# %% [markdown]
# <a href="https://colab.research.google.com/github/rajsahu2004/Well-Log-Case-Study/blob/main/code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget https://dnxxuwuw8tglo.cloudfront.net/Wells/P00524457.zip
# !wget https://dnxxuwuw8tglo.cloudfront.net/Wells/P00524458.zip
# !wget https://dnxxuwuw8tglo.cloudfront.net/Wells/P00524459.zip
# !unzip P00524457.zip
# !unzip P00524458.zip
# !unzip P00524459.zip
# !rm -rf *.zip
# Out:
# --2024-04-06 06:00:41--  https://dnxxuwuw8tglo.cloudfront.net/Wells/P00524457.zip
# Resolving dnxxuwuw8tglo.cloudfront.net (dnxxuwuw8tglo.cloudfront.net)... 13.32.84.162, 13.32.84.123, 13.32.84.173, ...
# Connecting to dnxxuwuw8tglo.cloudfront.net (dnxxuwuw8tglo.cloudfront.net)|13.32.84.162|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 565715004 (540M) [application/x-zip-compressed]
# Saving to: ‘P00524457.zip.1’
#
# P00524457.zip.1     100%[===================>] 539.51M  54.0MB/s    in 6.8s
#
# 2024-04-06 06:00:47 (79.3 MB/s) - ‘P00524457.zip.1’ saved [565715004/565715004]
#
# --2024-04-06 06:00:48--  https://dnxxuwuw8tglo.cloudfront.net/Wells/P00524458.zip
# Resolving dnxxuwuw8tglo.cloudfront.net (dnxxuwuw8tglo.cloudfront.net)... 13.32.84.162, 13.32.84.123, 13.32.84.173, ...
# Connecting to dnxxuwuw8tglo.cloudfront.net (dnxxuwuw8tglo.cloudfront.net)|13.32.84.162|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# ...

# %%
import os
import pandas as pd
from glob import glob
try:
  import lasio
except:
  # !pip -q install lasio
  import lasio

# %%
folders = glob('*of3')
folders
# Out:
# ['eno11801_gorgonichthys_1_1of3',
#  'eno11801_gorgonichthys_1_3of3',
#  'eno11801_gorgonichthys_1_2of3']

# %%
for folder in folders:
  print('*'*50)
  for a,b,c in os.walk(folder):
    print('a=',a)
    print('b=',b)
    print('c=',c)
# Out:
# **************************************************
# a= eno11801_gorgonichthys_1_1of3
# b= ['GORGONICHTHYS_1_S1R2_MSCT_DATA', 'GORGONICHTHYS_1_S1R1_PEX_DSI_DATA', 'GORGONICHTHYS_1_S1_PDS', 'GORGONICHTHYS_1_S1R3_VSP_DATA']
# c= ['Gorgonichthys1_LWD_ASCII_1820_4767.TXT', 'Gorgonichthys_1_LWD_1800_4767.txt', 'Gorgonichthys_1_PLAY_003.las', 'gorgonichthys1_uncorrected_logs.las', 'Gorgonichthys_1_suite3_supercombo_log.las', 'Gorgonichthys1_GR_log.xls', 'Gorgonichthys_1_recorded_final.PDS', 'Gorgonichthys_1_LWD1800_4764_temperature.txt', 'Gorgonichthys_1_formation_temperature.xls', 'Gorgonichthys_1_GR_DT.xls', 'Gorgonichthys_1_Surveys.xls', 'Gorgonichthys_1_Surveys.txt', 'gorgonichthys1_corrected_logs.las']
# a= eno11801_gorgonichthys_1_1of3/GORGONICHTHYS_1_S1R2_MSCT_DATA
# b= ['Graphics']
# c= ['r2s1_msct_sta_020.las', 'r2s1_msct_log_019.dlis', 'r2s1_msct_sta_020.dlis', 'r2s1_msct_sta_020.ver', 'r2s1_msct_log_019.ver']
# ...
